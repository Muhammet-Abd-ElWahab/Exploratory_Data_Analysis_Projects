# %% [markdown]
# # Project: Fleet Quality Analysis
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#Quest">Research Points</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# <li><a href="#Actions">Suggested Actions</a></li>
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
#
#
#
# > **Background:**
#  This investigation is for a food delivery application that helps people discover and order the food they will love. We have been largely focused on the food delivery and online ordering experience and our traction has been exponential. We aim to grow through a diverse set of channels while maintaining healthy economics.
#
# **The dataset description:**
#
# * Driver_Id: ID.
# * Date: Order date.
# * Pool: Delivery area.
# * Delivery_Time: The duration from customer request till order arrived.
# * Trip_Duration: The duration from runner acceptance till order arrived.
# * Pending_to_Dispatch: The duration from dispatch the order by user till accepted by runner.
# * FM: The duration from runner acceptance till arrived at restaurant.
# * EFM: The estimated duration from runner acceptance till arrived at restaurant through google map.
# * Waiting_Time: Waiting time in restaurant after driver arrived and before receiving order.
# * LM: The duration from receiving the order from the restaurant till order arrived.
# * ELM : The estimated duration from receiving the order from the restaurant till order arrived.
# * Delivered: Delivery status (0 or 1).
# * Total_Distance: Total distance between restaurant and customer address.
# * Hour: Order hour.
# * Late_FM: EFM - FM.
# * Late_LM: ELM - LM.
# * Total_Late: Late_FM + Late_LM.
# * Lateness_status: late or not (1 or 0).

# %% [markdown]
# <a id='Quest'></a>
# ## **Research Points:**
#
#
# 1. Delivery duration Per pool.
# 2. The percentage of late trip per pool.
# 3. The percentage of violators with late trips per pool.
# 4. LM & FM Lateness Trend per Hour.
# 5. Correlation Between:
# 	- Late_LM & Total_Distance
# 	- Late_LM & Waiting_Time
# 	- Late_FM & Total_Distance
# 	- Late_FM & Waiting_Time .
# 6. Drivers Evaluation.
# 7. Action plan to enhance the violators % per pool.

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > Now I'm going to explore this data and try to find patterns in it, compute statistics and visualize the relationships
# to answer the questions and detect the characteristics that affect patients attending to their hospital appointment

# %% [markdown]
# ### Research Point 1
# > ####  Delivery duration Per pool.

# %%
# Average Delivery_Time and Trip_Duration per pool
# Out:
#                              Trip_Duration  Delivery_Time
# Pool
# Zayed - Palm hills               45.976779      60.866300
# Madinaty                         43.923725      55.943340
# Haram & Faisal                   42.298519      55.964015
# Zayed - Districts                41.533864      53.644261
# Zaytoun & Ain Shams              40.977154      48.103619
# Alex East                        40.725214      51.345532
# Mokattam                         39.241104      47.491822
# Abbassya & Hadayek El Kobba      38.924360      52.590864
# Maadi - Zaharaa                  38.774846      50.052742
# New Cairo - Banks                38.352142      49.847172
# Alex West                        37.534807      48.835947
# Shoubra                          36.375435      51.199231
# Maadi - Corniche                 35.751500      44.422120
# Rehab                            35.295500      44.475816
# New Cairo - neighbourhoods       34.626544      46.584832
# ...

# %%
# Delivery_Time and Trip_Duration per pool bar chart (Worst 10)

# %%
# Best 5 Pools in Average Delivery_Time and Trip_Duration
# Out:
#                   Trip_Duration  Delivery_Time
# Pool
# Ras Sudr              11.236640      22.346660
# Tanta                 24.159175      35.540402
# El Mansoura           26.593146      36.775163
# 1-Oct                 30.442134      37.664791
# Hadayek El Ahram      32.321606      38.697376

# %%
# Delivery_Time and Trip_Duration per pool bar chart (Best 5)

# %% [markdown]
# ### Result 1:
#
# **1. The worst ten pools in both average Trip_Duration and average Delivery_time average are:**
#
#     - Zayed - Palm hills.
#     - Madinaty
#     - Haram & Faisal
#     - Zayed - Districts
#     - Zaytoun & Ain Shams
#     - Alex East
#     - Mokattam
#     - Abbassya & Hadayek El Kobba
#     - Maadi - Zaharaa
#     - New Cairo - Banks
#
# **2. The best five pools in both average Trip_Duration and average Delivery_time are:**
#
#     - Hadayek El Ahram.
#     - 1-Oct
#     - El Mansoura
#     - Tanta
#     - Ras Sudr
#
# **3. The Pending_to_Dispatch average time is the highest in:**
#
#     - Zayed - Palm hills (14.89) min on average
#     - Haram & Faisal (14:88) min on average (13.67)min on average
#     - Abbassya & Hadayek El Kobba.(13.67) min on average

# %% [markdown]
# ### Research Point 2
# > #### The percentage of late trip per pool.

# %%
# Lateness percentage per pool LM of FM
# Out:
# Pool
# Tanta                          17.688266
# El Mansoura                    33.275261
# New Cairo - AUC                36.931818
# 1-Oct                          38.356164
# Nasr City                      47.188049
# Abbassya & Hadayek El Kobba    48.623853
# Ras Sudr                       50.000000
# M.D.A.Z                        50.120337
# New Cairo - neighbourhoods     51.967213
# Zayed - Districts              54.005525
# Heliopolis - Sheraton          56.470588
# Madinaty                       57.754011
# Rehab                          57.809695
# Maadi - Corniche               57.883050
# Heliopolis - Korba             59.926918
# Zaytoun & Ain Shams            60.126582
# Alex West                      60.990338
# New Cairo - Banks              61.633663
# Maadi - Zaharaa                61.666667
# Shoubra                        62.566845
# Hadayek El Ahram               63.963964
# Haram & Faisal                 64.062500
# Mokattam                       65.497076
# ...

# %%
# Lateness Percentage per pool bar plot

# %% [markdown]
# ### Result 2:
#
# **1. The worst ten pools on Lateness Percentage are:**
#
#     (Late_LM or Late_FM more than or equal to 5 Minutes)
#
#     - Alex East                      68.66 % Latness
#     - Zayed - Palm hills             65.56 % Latness
#     - Mokattam                       65.50 % Latness
#     - Hadayek El Ahram               64.25 % Latness
#     - Haram & Faisal                 64.06 % Latness
#     - Shoubra                        63.59 % Latness
#     - Maadi - Zaharaa                62.21 % Latness
#     - New Cairo - Banks              61.94 % Latness
#     - Alex West                      61.21 % Latness
#     - Zaytoun & Ain Shams            60.51 % Latness

# %% [markdown]
# ### Research Point 3
#
# > #### The percentage of violators with late trips per pool.

# %%
#  Violators Lateness Percentage per pool
# Out:
#                              Total_Drivers  Violators_Drivers  \
# Pool
# Alex East                              365                252
# Zayed - Palm hills                     300                198
# Mokattam                               170                112
# Hadayek El Ahram                       220                142
# Shoubra                                182                117
# Haram & Faisal                         383                246
# Maadi - Zaharaa                       1128                703
# New Cairo - Banks                      400                249
# Alex West                              823                505
# Zaytoun & Ain Shams                    155                 95
# Heliopolis - Korba                     820                492
# Maadi - Corniche                      1343                782
# Madinaty                               559                324
# Rehab                                  556                322
# ...

# %%
# Violators Lateness Percentage per pool bar plot

# %% [markdown]
# ### Result 3:
#
# **1. The worst ten pools on Violators percentage in FM or LM are:**
#
#
#     - Alex East             69.04 %
#     - Zayed - Palm hills    66.00 %
#     - Mokattam              65.88 %
#     - Hadayek El Ahram	  64.55 %
#     - Shoubra	   	    64.29 %
#     - Haram & Faisal	    64.23%
#     - Maadi - Zaharaa	   62.32%
#     - New Cairo - Banks	 62.25%
#     - Alex West	         61.36%
#     - Zaytoun & Ain Shams   61.29%
#
#
#
#
#         -

# %% [markdown]
# ### Research Point 4
#
# > #### LM & FM Lateness Trend per Hour

# %%
# LM & FM Lateness Trend per Hour line trend per hour
                                                        # LM + FM Lateness Trend per Hour line trend per hour

# %%
# Check distribution of variables

# %% [markdown]
# **There is no skewness in variables distributions that indicates any strong point related to Lateness time.**

# %% [markdown]
# ### Result 4:
#
# **From above visualizations we can see that:**
#
#     - The highest LM Lateness at 18:00 O'clock.
#     - The highest FM Lateness at 21:00 O'clock.
#     - Total Lateness of LM + FM is the highest at 18 O'clock.
#
# **So we need to pay more effort on hours between 18 and 21 to decrease Lateness time like raise EFM and ELM time a little**

# %% [markdown]
# ### Research Point 5
#
# > #### Correlation Between Late_LM and Total_Distance.
# > #### Correlation Between Late_LM and Waiting_Time.
# > #### Correlation Between Late_FM and Total_Distance.
# > #### Correlation Between Late_FM and Waiting_Time .

# %%
# Check correlation map

# %%
# Scatter plot Late_LM vs Total_Distance
                                            # Scatter plot Late_FM vs Total_Distance

# %%
# Scatter plot Late_LM vs Waiting_Time
                                            # Scatter plot Late_FM vs Waiting_Time

# %% [markdown]
# ### Result 5:
#
# **From above visualizations we can see that:**
#
#     - There is no correlation between Waiting_Time and Late_LM.
#     - There is no correlation between Waiting_Time and Late_FM.
#     - There is no correlation between Total_Distance and Late_LM.
#     - There is no correlation between Total_Distance and Late_FM.

# %% [markdown]
# ### Research Point 6
#
# > #### Drivers Evaluation

# %%
# Drivers with Lateness percentage between 70% and 90 % which made more than 10 orders
# Out:
#                            Pool                             Driver_Id  \
# 4                     Alex East  0c2f3af2-6b78-400b-9f28-a1d5b6076132
# 18                    Alex West  ad95df21-a01c-49ef-b58c-2a056c07c206
# 16                    Alex West  99b149c9-7934-46c5-bfbb-caa3e54ff8b5
# 15                    Alex West  7d9467d4-5a2c-46e3-8820-ae51ec7b1ee6
# 11                    Alex West  47321a43-9a50-452f-8d0a-1696020abdd7
# 10                    Alex West  3569dbf4-8c1e-423e-81e8-4f653b1b0424
# 9                     Alex West  33693d7a-0ba7-4e46-8db1-aaaf531ac120
# 12                    Alex West  5b1c7cbf-3d42-4382-978c-50221e33c68e
# 7                     Alex East  a83ce027-cc9d-456b-80ec-45976d662bfb
# 19                    Alex West  bd0e956e-4451-48e3-ac12-abdeef470792
# 3                     Alex East  01e80b89-97c2-4548-91cd-56cac616741c
# 14                    Alex West  76737f90-b42a-401b-9238-47bcfb06514d
# ...

# %%
# Drivers with Lateness percentage more than 90 % which made more than 10 orders
# Out:
#                      Pool                             Driver_Id  \
# 19               Madinaty  62b2815a-82e6-4707-9b38-78bf196661ee
# 18        Maadi - Zaharaa  4fdba9c8-ad22-4cc3-a560-63b5d71d46cb
# 4          Haram & Faisal  8e914b9b-d1e1-4c00-9c1f-a6dd524754d2
# 17        Maadi - Zaharaa  481acb7d-16c4-4cfa-ba1f-cedec72b926b
# 6      Heliopolis - Korba  5963ef33-bbaa-4af5-9d06-610a8b70d596
# 16       Maadi - Corniche  bb1556e8-0840-421d-8d5a-9c6651b7a26d
# 9                 M.D.A.Z  146f58b1-c9c2-4c65-86ec-2a87ec4e966c
# 15       Maadi - Corniche  9a43924f-a112-48fe-8dbe-b6b584b02704
# 12                M.D.A.Z  a1723122-4551-4d5f-a3ba-7087b0f181ec
# 8   Heliopolis - Sheraton  23a923f9-17a6-48d5-aa6f-2375634a50f4
# 3          Haram & Faisal  8e826a72-45b8-4e4a-b73b-3885ed262ead
# 1               Alex East  edbae21d-88aa-49f2-95de-f7f2695bbf1d
# 13       Maadi - Corniche  3509178a-f779-4a67-bd4b-52995921ee6d
# 10                M.D.A.Z  857a000f-f8f9-445f-a526-c063df8d58c0
# ...

# %% [markdown]
# ## Drivers data attached into two sheets

# %% [markdown]
# ### Result 6:
#
# **I divided drivers data into 2 different sheets:**
#
# >     1. Drivers_need_coaching sheet includes Drivers who have Lateness_Percentage between 70% and 90% and Orders Counts more than 10.
#
# >     2. Drivers_need_actions sheet includes Drivers who have Lateness_Percentage more than 90 % and order counts more than 10.
#
#
# **From all previous data and visualization we statistically suggest these actions:**
#
# >     - Observe the first group, make fast meetings with them and try to find the reason behind the high lateness percentage from total orders they delivered.
#
# >     - Observe the second group as well and take the necessary actions with them.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
#
#
# **1. The highest average for Trip_Duration and Delivery_time is in:**
#
#      - Zayed - Palm hills
#      - Madinaty
#      - Haram & Faisal Pools have
#
# **2. The Pending_to_Dispatch average time is the highest in:**
#
#     - Zayed - Palm hills (14.89) min.
#     - Haram & Faisal (14:88) min on average (13.67) min.
#     - Abbassya & Hadayek El Kobba.(13.67) min.
#
# **3. The worst pools on Lateness Percentage are:**
#
#
#     - Alex East                      68.66 % Lateness   (Late_LM or Late_FM more than or equal to 5 Minutes)
#     - Zayed - Palm hills             65.56 % Lateness
#     - Mokattam                       65.50 % Lateness
#
# **4. Alex East, Zayed - Palm hills and Mokattam Pools have the highest Violators percentage in LM or FM with 69%, 66% and 65.88 respectively.**
#
#
# **5. We need to pay more effort on hours between 18:00 and 21:00 O'clock to decrease Lateness time:**
#
#     - The highest LM Lateness value at 18:00 O'clock.
#     - The highest FM Lateness value at 21:00 O'clock.
#     - Total Lateness of LM + FM is the highest at 18 O'clock.
#
# **6. There are no correlations that affect Lateness time in this dataset.**

# %% [markdown]
# <a id='Actions'></a>
#
# ## Suggested Actions
#
#
#
# **1. - Every Pool manager should observe Drivers with Lateness Percentage between 70% and 90%, make fast meeting with them and try to find the reason behind high lateness percentage from total orders they delivered.**
#
# **2. - Observe Drivers with Lateness Percentage more than 90% as well you may find another issues with their performance. Take the necessary actions with them**
#
# **3. Collect more data about drivers to analyze their behaviour and find out the reasons behind high lateness percentage to avoid in the future**
#
# **4.Pay more effort on hours between 18:00 O'clock and 21:00 O'clock:**
#
#      - Raise EFM and ELM time a little to avoid lateness.
#      - Manage breaks to not intersect with this period.

# %% [markdown]
# ## Limitations
#
# **1.  There is a lot of empty values in each columns specially columns that indicates lateness which may affect our analysis accuracy.**
#
# **2.There are typing or data entry issues. Delivery_Time couldn't be 2198 minutes and Late_FM couldn't be - 86.8.**
#
# **3.Finally to evaluate Drivers performance effectively we need more data about them like their behavior and working hours and customer rating.**
